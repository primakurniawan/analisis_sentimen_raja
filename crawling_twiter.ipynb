# %%
import tweepy
import pandas as pd
from tqdm import tqdm

client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAKYYgQEAAAAA7V0jpne%2BzF6WlwPkjDUQa%2FostWo%3DSDmxDGORJ9tznP3AhEIFbkRsxoOUFQoe9x4YCluQCjrKkgpCYB', consumer_key='xgjL461YTiWyJ0gyApVFnQK3M', consumer_secret='6jRnYn6ANu5QaFrY3rpBzQDxAzZ26gUHGWq9PjDUZejz7O4lfG', access_token='1436172342678286339-OUJose0JedCxmwatvbUlHsEwmlfY1I', access_token_secret='dU2pIBijcZcywJlOuaIJAeLlkE75Br9SN4nD76TkeImiJ',)

# Replace with your own search query
query = 'omicron tinggi'

file_name = query+'.xlsx'

tweets=[]
# Replace the limit=1000 with the maximum number of Tweets you want
for tweet in tweepy.Paginator(client.search_recent_tweets, query=query, max_results=100).flatten(limit=10000):
    if (tweet.text not in tweets):
        tweets.append(tweet.text)
data = pd.DataFrame(tweets)
data.to_excel(file_name, index=False)
print ('berhasil menyimpan data '+ file_name)
# Out:
# berhasil menyimpan data omicron tinggi.xlsx

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
tweets = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('omicron lang:id').get_items()):
    if i>50000:
        break
    if 'omicron' in tweet.content:
        tweets.append(tweet)
    
# Creating a dataframe to load the list
tweets_df = pd.DataFrame(tweets)
tweets_df['date'] = tweets_df['date'].apply(lambda a: pd.to_datetime(a).date()) 
tweets_df.to_excel('omicron.xlsx')
tweets_df
# Out:
#                                                      url        date  \
# 0      https://twitter.com/noturfavgerl/status/156227...  2022-08-24
# 1      https://twitter.com/SandalJ33651908/status/156...  2022-08-24
# 2      https://twitter.com/garuda080/status/156224366...  2022-08-24
# 3      https://twitter.com/galerifitri/status/1562243...  2022-08-24
# 4      https://twitter.com/erny_siswati/status/156222...  2022-08-23
# ...                                                  ...         ...
# 21049  https://twitter.com/WahyuNrAgstin/status/14950...  2022-02-19
# 21050  https://twitter.com/maapketiduran/status/14950...  2022-02-19
# 21051  https://twitter.com/lapakloki/status/149509035...  2022-02-19
# 21052  https://twitter.com/rizkypranst/status/1495089...  2022-02-19
# 21053  https://twitter.com/cenutcelekit/status/149508...  2022-02-19
#
#                                                  content  \
# 0                              Semoga g omicron ya Tuhan
# 1      @dinagustavsson Ada delta,omicron ,cacar munyu...
# 2      Ayo sukseskan vaksinasi Covid-19 dengan melaku...
# 3      Agar terhindar dr varian baru omicron BA.4 &am...
# 4      Ambil baik nya, pas kenapa omicron, pertama bi...
# ...                                                  ...
# 21049  Adekk cintak nggak selalu indah dek, omicron a...
# 21050  hari ini menyenangkan,\npagi - sore: istirahat...
# 21051  @pacarbighit dirumahh, yang nobar hati2 omicro...
# 21052                @helloverrrr W lg kena omicron haha
# 21053      @tubbirfess Ini gw lagi omicron anjg bgsttttt
#
#                                          renderedContent                   id  \
# 0                              Semoga g omicron ya Tuhan  1562274507465039873
# 1      @dinagustavsson Ada delta,omicron ,cacar munyu...  1562261673603239936
# 2      Ayo sukseskan vaksinasi Covid-19 dengan melaku...  1562243666017923072
# 3      Agar terhindar dr varian baru omicron BA.4 &am...  1562243395837644801
# 4      Ambil baik nya, pas kenapa omicron, pertama bi...  1562227603741614080
# ...                                                  ...                  ...
# 21049  Adekk cintak nggak selalu indah dek, omicron a...  1495091303247675393
# 21050  hari ini menyenangkan,\npagi - sore: istirahat...  1495091219344420866
# 21051  @pacarbighit dirumahh, yang nobar hati2 omicro...  1495090358706847746
# 21052                @helloverrrr W lg kena omicron haha  1495089985472843776
# 21053      @tubbirfess Ini gw lagi omicron anjg bgsttttt  1495088380568547328
#
#                                                     user  replyCount  \
# 0      {'username': 'noturfavgerl', 'id': 72086429442...           0
# 1      {'username': 'SandalJ33651908', 'id': 13768970...           0
# 2      {'username': 'garuda080', 'id': 128641833, 'di...           3
# 3      {'username': 'galerifitri', 'id': 577026915, '...           4
# 4      {'username': 'erny_siswati', 'id': 608912929, ...           1
# ...                                                  ...         ...
# 21049  {'username': 'WahyuNrAgstin', 'id': 2381986500...           0
# 21050  {'username': 'maapketiduran', 'id': 468231066,...           0
# 21051  {'username': 'lapakloki', 'id': 14823891605396...           0
# 21052  {'username': 'rizkypranst', 'id': 224616737, '...           0
# 21053  {'username': 'cenutcelekit', 'id': 14895662252...           0
#
#        retweetCount  likeCount  quoteCount  ...  \
# 0                 0          0           0  ...
# 1                 0          1           0  ...
# 2                13         15           4  ...
# 3                11         12           2  ...
# 4                 0          0           0  ...
# ...             ...        ...         ...  ...
# 21049             0          0           0  ...
# 21050             0          0           0  ...
# 21051             0          0           0  ...
# 21052             0          0           0  ...
# 21053             0          0           0  ...
#
#                                                    media retweetedTweet  \
# 0                                                   None           None
# 1                                                   None           None
# 2      [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 3      [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 4                                                   None           None
# ...                                                  ...            ...
# 21049  [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 21050                                               None           None
# 21051                                               None           None
# 21052                                               None           None
# 21053                                               None           None
#
#       quotedTweet inReplyToTweetId  \
# 0            None              NaN
# 1            None     1.562260e+18
# 2            None              NaN
# 3            None              NaN
# 4            None              NaN
# ...           ...              ...
# 21049        None              NaN
# 21050        None              NaN
# 21051        None     1.495088e+18
# 21052        None     1.495070e+18
# 21053        None     1.495031e+18
#
#                                            inReplyToUser  \
# 0                                                   None
# 1      {'username': 'dinagustavsson', 'id': 153079039...
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 21049                                               None
# 21050                                               None
# 21051  {'username': 'pacarbighit', 'id': 2805255902, ...
# 21052  {'username': 'helloverrrr', 'id': 111955892357...
# 21053  {'username': 'tubbirfess', 'id': 8725720753402...
#
#                                           mentionedUsers  \
# 0                                                   None
# 1      [{'username': 'dinagustavsson', 'id': 15307903...
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 21049                                               None
# 21050                                               None
# 21051  [{'username': 'pacarbighit', 'id': 2805255902,...
# 21052  [{'username': 'helloverrrr', 'id': 11195589235...
# 21053  [{'username': 'tubbirfess', 'id': 872572075340...
#
#                                             coordinates  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 21049  {'longitude': 107.110619, 'latitude': -6.346219}
# 21050                                              None
# 21051                                              None
# 21052                                              None
# 21053                                              None
#
#                                                    place  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 21049  {'fullName': 'Lemahabang, Indonesia', 'name': ...
# 21050                                               None
# 21051                                               None
# 21052                                               None
# 21053                                               None
#
#                                                 hashtags cashtags
# 0                                                   None     None
# 1                                                   None     None
# 2      [TetapProkesLengkapiVaksin, IndonesiaSemakinHe...     None
# 3      [TetapProkesLengkapiVaksin, IndonesiaSemakinHe...     None
# 4                                         [gaptekdotcom]     None
# ...                                                  ...      ...
# 21049                                               None     None
# 21050                                               None     None
# 21051                                               None     None
# 21052                                               None     None
# 21053                                               None     None
#
# [21054 rows x 27 columns]

# %%
tweets_df.to_csv('omicron.csv')
